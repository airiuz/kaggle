# %% [markdown]
# # Neyron tarmoq o'zi nima?

# %% [markdown]
# Neyron tarmoq - bu sinapslar orqali bog'langan neyronlar ketma-ketligi. Neyron tarmog'ining tuzilishi dasturlash dunyosiga to'g'ridan-to'g'ri biologiyadan kelgan. Ushbu tuzilma tufayli mashina turli xil ma'lumotlarni tahlil qilish va hatto yodlash qobiliyatiga ega bo'ladi. Neyron tarmoqlar nafaqat kiruvchi ma'lumotni tahlil qilish, balki ularni xotiradan qayta tiklashga ham qodir. Boshqacha qilib aytganda, neyron tarmoq - bu elektr impulslari shaklida ma'lumot uzatuvchi millionlab neyronlarni o'z ichiga olgan inson miyasining mashina talqini.

# %% [markdown]
# ## Biologik neyron

# %% [markdown]
# <img src="https://cf2.ppt-online.org/files2/slide/h/hljIGMRUdk4giTaPn6uSxWOw0zeDVLAqH8FsXQ2Jb/slide-29.jpg">

# %% [markdown]
# ## Sun'iy Neyron Tarmoq

# %% [markdown]
# Har bir aylana bu neyron tarmoq faqat bu biologik neyron tarmoq emas bu raqamli sun'iy tarmoq
#
# Yuqoridagi visual rasmdan ko'rinib turibdiki tarmoqdagi har bir neyron o'zidan keyingi neyronlarga ulangan bo'lib bu har bir neyron o'zidan qandaydir ma'lumot(signal) ni keyingi har bir neyronga jo'natadi va shundan butun bir o'zaro bog'liq neyron sistema paydo bo'ladi buni zamonaviy tilda Sun'iy Neyron Tarmoq(Artificali Neural Network) deb nomlangan
#
# Hozircha biz neyron tarmoqlarning eng asosiy turi bo'yicha misollarni ko'rib chiqamiz - bu to'g'ridan-to'g'ri tarqatish tarmog'i,nomidan ko'rinib turibdiki, neyron qatlamlarning ketma-ket ulanishiga ega bo'lgan tarmoq bo'lib, unda ma'lumotlar doimo faqat bitta yo'nalishda oqadi.

# %% [markdown]
# <img src="https://habrastorage.org/r/w1560/getpro/habr/post_images/947/cdd/918/947cdd91841e5ec69db32eddb7a070e9.jpg">

# %% [markdown]
# ## Neyron tarmoqlar nima uchun?

# %% [markdown]
# Neyron tarmoqlar inson miyasi bajaradigan narsaga o'xshash analitik hisob-kitoblarni talab qiladigan murakkab muammolarni hal qilish uchun ishlatiladi. Neyron tarmoqlarning eng keng tarqalgan turlari:

# %% [markdown]
# **`Tasniflash (Klassifikatsiya)`** - ma'lumotlarni parametrlar bo'yicha taqsimlash. Misol uchun, odamlar to'plami kirish sifatida berilgan va siz ulardan qaysi biriga kredit berishni va bermasligini hal qilishingiz kerak. Bu ishni neyron tarmoq yordamida amalga oshirish mumkin, neyron tarmoq bu odamlarning ba'zi parametrlariga qarab o'zi xulasa chiqarishi mumkin masalan: yosh, jinsi, maoshi,to'lov qobiliyati, kredit tarixi va boshqalar.</br>
# </br>
# **`Bashorat`** - keyingi qadamni bashorat qilish qobiliyati. Masalan, qimmatli qog'ozlar bozoridagi vaziyatdan kelib chiqqan holda qimmatli qog'ozlarning ko'tarilishi yoki tushishi yoki ob-havoni ertaga qanday bo'lishi va h.k</br>
# </br>
# **`Obyektni aniqlash`** - hozirda eng keng tarqalgan neyron tarmoq hisoblanadi. Googleda surat qidirganda yoki telefon kameralarida yuzingiz holatini aniqlab, uni ajratib koʻrsatish va boshqalarda foydalaniladi.</br>

# %% [markdown]
# ## Neyron Tarmoq qanday ishlaydi?

# %% [markdown]
# Neyron - bu axborotni qabul qiluvchi, u bo'yicha oddiy hisob-kitoblarni amalga oshiradigan va keyingi neyronga uztuvchi tugun.</br>
# Neyron tarmoq asosan 3 qismga bo'linadi</br>
#
# 1. Kiruvchi(qizil)</br>
# 2. Yashirin(ko'k, binafsha)</br>
# 3. Chiquvchi(yashil)</br>
#
# Agar neyron tarmoq ko'p sonli neyronlardan iborat bo'lsa, qatlam atamasi kiritiladi. Shunga ko'ra, axborotni qabul qiluvchi kirish qatlami, uni qayta ishlovchi n ta yashirin qatlam va natijani ko'rsatadigan chiqish qatlami mavjud. Neyronlarning har biri ikkita asosiy parametrga ega: kirish ma'lumotlari (input data) va chiqish ma'lumotlari (output data). Kirish qatlamidagi neyronlar ma'lumotlarni hechqanday hisob kitob ishlari qilinmaydi va qolganlarida, oldingi qatlamdagi barcha neyronlarning umumiy ma'lumotlarini o'z ichiga oladi, shundan so'ng u faollashtirish funktsiyasi(Activation function) yordamida normallashtiriladi (hozircha uni f (x) tasavvur qiling) va chiqish qatlamiga kiradi.( aktivatsiya funksiyalari va normallashtirish haqida batafsil to'xtalamiz)

# %% [markdown]
# <img src="data:image/jpeg;base64,...">

# %% [markdown]
# Aktivatsiya funksiyalarining bir nechtasi bilan tanishib olamiz

# %% [markdown]
# <img src="https://i.pinimg.com/originals/44/3d/25/443d25218a81e4bd8bac8d954c866a1b.png">

# %% [markdown]
# activation function lar haqida batafsil o'qish uchun ushbu [maqola](https://medium.com/analytics-vidhya/activation-functions-all-you-need-to-know-355a850d025e) ustiga bosing

# %% [markdown]
# Neyron tarmoqning qanday ishlashini oddiy bir misolda ko'ramiz

# %% [markdown]
# Bizga quyidagicha ma'lumotlar berilgan bo'lsin
#
#
# <img src="data:image/jpeg;base64,...">

# %% [markdown]
# x1, x2, x3 qiymatlardan y hosil bo'ladigan shunday w1, w2, w3 va b koeffitsent topish kerak va keyingi kelgan 1 2 3 sonlar uchun y ni bashorat qilish kerak
# Ba'zi bir tushunchalar bilan tanishamiz. Bu yerda x1, x2,x3 - features (xususiyat, fazilat) deyiladi bizning misolimizda ularning soni 3 ta lekin real loyihalarda millionlab bo'lishi mumkin ularning soniga hech qanday cheklov mavjud emas</br>
# 1,2,3,4 qatorlar bu yerda sample lar deyiladi sample lar soni qancha ko'p bo'lsa sun'iy neyron tarmoq ning aniqlilik darajasi shunchalik yuqori bo'ladi.</br>
# y - ustun (target value) deyiladi
#
# w1, w2, w3 - weights lar deb nomlanadi(og'irlik, koeffitsent)
# b - bias (erkin koeffitsent)
#
# Shunday Sun'iy tarmoq tuzishimiz kerakki u 1 2 3 sonlaridan qanday qilib 1 yoki 1 -3 0 sonlaridan qanday qilib -6 paydo bo'lganligini aniqlab bizga 3 1 -2 qiymatlarda y nimaga teng ekanligini bashorat qilib berishi kerak

# %% [markdown]
# <img src="https://miro.medium.com/max/1400/1*-uNOPSyB7IOk9inA-brIBg.png">

# %%
import numpy as np

# %% [markdown]
# <img src="data:image/jpeg;base64,...">

# %% [markdown]
# Sun'iy neyron tarmoq quyidagi qadamlarni bajaradi.</br>
# ## **` 1-qadam `** </br>
# Forward(oldinga) hisoblashda y_bashorat hisoblab topiladi

# %% [markdown]
# ## **` 2-qadam `** </br>
# Xatolik(Loss) topiladi - Xatolikni aniqlash quyidagicha bo'ladi
#
# Umuman sun'iy neyron tarmoq hal qilishi kerak bo'lgan masalalar 2 turga ajratiladi.
# 1. Regressiya
# 2. Classification
#
# Regressiya - bu aniq bir qiymatni bashorat qiluvchi SNT(sun'iy neyron tarmoq)</br>
# Classification - berilgan obyekt ma'lum bir classga tegishli ekanligini aniqlaydigan SNT</br>
# masalan: bizda 10 000 ta it va mushuk rasmlaridan iborat 224x224 px ma'lumotlar bor biz bu ma'lumotlarni SNT ga o'qitamiz va ixtiyoriy rasm jo'natsak bizga bu itmi yoki mushuk ekanligini bashorat qilib beradi.

# %% [markdown]
# <img src="https://miro.medium.com/max/1400/1*IhP8BdoUpAbssltq0VBafg.png">

# %% [markdown]
# Xatolik funksilari(Loss function)
# 1. O'rtacha kvadratik xatolik(Mean Squared Error {MSE}) </br>
# <img src="https://miro.medium.com/v2/resize:fit:640/format:webp/1*kjfms6RCnHVMLRSq75AD0Q.png"> </br>
# y - haqiqiy qiymat</br>
# y_bash - SNT bashorat qilgan qiymat</br>
# n - simple lar soni</br>

# %% [markdown]
# 2. O'rtacha Absolut Xatolik(Mean Absolute Error {MAE}) </br>
# <img src="https://miro.medium.com/v2/resize:fit:640/format:webp/1*78B4XwuVtBbacdTFIkjOXQ.png">

# %% [markdown]
# 3. Binary Cross Entropy </br>
# Binary Cross Entropy - Bu ikkilik tasniflash modellarida ishlatiladigan xatolik(yo'qotish) funktsiyasi - bu erda model kirish ma'lumoti oldindan o'rnatilgan ikkita toifadan biriga tasniflashi kerak.</br>
# pi - ehtimollik ( berilgan rasm itga va mushukka necha % o'xshashligi)
# <img src="https://miro.medium.com/v2/resize:fit:1400/format:webp/1*gbe2JiIk6Vsf32ulhhahCA.png">

# %% [markdown]
# 4. Categorical Cross-Entropy Loss </br>
# Sinflar soni ikkitadan ko'p bo'lgan hollarda biz toifali o'zaro entropiyadan foydalanamiz - bu ikkilik o'zaro entropiyaga juda o'xshash jarayondan keyin.</br>
# m - kotegoriyalar soni
#
# <img src="https://miro.medium.com/v2/resize:fit:720/format:webp/1*HOCJtpCyQzWX8Xp3H8Ez2w.png">

# %% [markdown]
# Loss Functionlar haqida to'liq [ma'lumot](https://towardsdatascience.com/loss-functions-and-their-use-in-neural-networks-a470e703f1e9#:~:text=A%20loss%20function%20is%20a,value%20of%20J%20(average%20loss)) olish uchun ushbu maqolani o'qib chiqishingizni tavsiya bergan bo'lar edim

# %% [markdown]
# ## **` 3-qadam `** </br>
# Backward propagation - teskari hisob kitob - bu jarayonida tasodifiy tanlab olingan weights va bias lar ni Loss minimal qiymatga erishgunga qadar Gradient kamaytiriladi.

# %%
import numpy as np

# %%
x = np.array([[1,1,-4,5],
              [2,-3,5,0.5],
              [3,0,3,1]], dtype=np.float32)

y = np.array([[1,-6, 2, 4]], dtype=np.float32) # y(target value) ustun qiymatlari

# %%
class modelANN:
    def __init__(self,input_size,output_size):
        self.weights = np.random.rand(input_size,output_size) - 0.5
        self.bias = np.random.rand(1,output_size) - 0.5
        
    def get_info(self):
        return self.weights,self.bias
    
    def forward_propagation(self,input_data):
        self.input = input_data
        self.output = np.dot(self.input,self.weights) + self.bias
        return self.output
    
    def backward_propagation(self,output_error,learning_rate):
        input_error = np.dot(output_error, self.weights.T)
        weights_error = np.dot(self.input.T, output_error)
        # dbias = output_error
        
        self.weights -= learning_rate * weights_error
        self.bias -= learning_rate * output_error
        return input_error

# %%
class Activation_Layer:
    def __init__(self,activation,activation_prime):
        self.activation = activation
        self.activation_prime = activation_prime
        
    def forward_propagation(self,input_data):
        self.input = input_data
        self.output = self.activation(self.input)
        return self.output
    
    def backward_propagation(self,output_error,learning_rate):
        return self.activation_prime(self.input) * output_error

# %%
def sigmoid(x):
    return 1 / (1+np.exp(-x))

def sigmoid_prime(x):
    sigmoid = 1 / (1+np.exp(-x))
    return sigmoid * (1 - sigmoid)

# %%
def tanh(x):
    return np.tanh(x)

def tanh_prime(x):
    return 1 - np.tanh(x)**2

# %%
def mse(y_true, y_pred):
    return np.mean(np.power((y_true-y_pred), 2))

# def mse_prime(y_true, y_pred):
#     return (y_pred - y_true)**2 / y_true.size

def mse_prime(y_true, y_pred):
    return 2*(y_pred - y_true) / y_true.size

# %%
class Network:
    def __init__(self):
        self.layers = []
        self.loss = None
        self.loss_prime = None
        
    def add(self, layer):
        self.layers.append(layer)
        
    def use(self,loss,loss_prime):
        self.loss = loss
        self.loss_prime = loss_prime
        
    def predict(self,input_data):
        samples = len(input_data)
        result = []
        
        for i in range(samples):
            output = input_data[i]
            for layer in self.layers:
                output = layer.forward_propagation(output)
            result.append(output)
        return result
    
    def fit(self,x_train,y_train,epochs,learning_rate):
        samples = len(x_train)
        
        for i in range(epochs):
            err = 0
            for j in range(samples):
                output = x_train[j]
                for layer in self.layers:
                    output = layer.forward_propagation(output)
                    
                err += self.loss(y_train[j],output)
                error = self.loss_prime(y_train[j],output)
                
                for layer in reversed(self.layers):
                    error = layer.backward_propagation(error,learning_rate)
            err = err / samples
            
            if i%100==0:
                print(f"{i+1}/{epochs}    loss = {err}")

# %%
model = Network()
model.add(modelANN(3,2))
model.add(Activation_Layer(tanh,tanh_prime))
model.add(modelANN(2,1))

# %%
x_train = np.array([[[1,2,3]], [[1,-3,0]], [[-4,5,3]],[[5,0.5,1]], [[2,2,0]],[[-1.5,6,3]],[[3,-8,1]]])
y_train = np.array([[[1]], [[-6]], [[2]], [[4]],[[5]],[[6.5]],[[-15]]])

# %%
model1.use(mse,mse_prime)
model1.fit(x_train,y_train,epochs=1000,learning_rate=0.01)
